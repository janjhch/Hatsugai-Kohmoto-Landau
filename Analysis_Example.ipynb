# %%
from HKLnumerics import HK_1D, PlotFunctions

mu_U8_1d = HK_1D.create_mu_array(500, 8)
mu_U1_1d = HK_1D.create_mu_array(500, 1)

rho_u8_1d = HK_1D.create_rho_array(mu_U8_1d, 8)
rho_u1_1d = HK_1D.create_rho_array(mu_U1_1d, 1)

PlotFunctions.two_graphs_in_one_plot(rho_u1_1d, rho_u8_1d, mu_U1_1d, mu_U8_1d,
                                     r'$U = 1$', r'$U = 8$', r'$\mu$', r'$d = 1$')
# Out:
# Progress: 99.8%
